# %% [markdown]
# # Pandas Dataframe

# %%
import pandas as pd

# %% [markdown]
# #empty df:

# %%
d = pd.DataFrame()

# %%
d
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
d.shape
# Out:
# (0, 0)

# %%
d.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 0 entries
# Empty DataFrame

# %%
country = ["BD","India","Pak","Nepal","Sri"]

# %%
country
# Out:
# ['BD', 'India', 'Pak', 'Nepal', 'Sri']

# %%
saarc = pd.DataFrame(country)

# %%
saarc
# Out:
#        0
# 0     BD
# 1  India
# 2    Pak
# 3  Nepal
# 4    Sri

# %%
saarc.shape
# Out:
# (5, 1)

# %%
saarc = pd.DataFrame(country, columns = ['countryname'], index = ['n1','n2','n3','n4','n5'])
saarc
# Out:
#    countryname
# n1          BD
# n2       India
# n3         Pak
# n4       Nepal
# n5         Sri

# %%
country2 = ['America','Germany','England','Ireland','Norway']
country2
# Out:
# ['America', 'Germany', 'England', 'Ireland', 'Norway']

# %%
who = pd.DataFrame(country2, columns = ['countryname2'])

# %%
who
# Out:
#   countryname2
# 0      America
# 1      Germany
# 2      England
# 3      Ireland
# 4       Norway

# %%
combind = pd.DataFrame(zip(country,country2), columns = ["saarc","who"],index = ["c1",'c2','c3','c4','c5'])
combind
# Out:
#     saarc      who
# c1     BD  America
# c2  India  Germany
# c3    Pak  England
# c4  Nepal  Ireland
# c5    Sri   Norway

# %%
combind.shape
# Out:
# (5, 2)

# %%
L = [["mango","banana","lichy"],["rose","bela","lily"],["potato","bean","chili"]]
L
# Out:
# [['mango', 'banana', 'lichy'],
#  ['rose', 'bela', 'lily'],
#  ['potato', 'bean', 'chili']]

# %%
M = pd.DataFrame(L, index=['fruits','flowers','veg'],columns= ['c1','c2','c3'])

# %%
M
# Out:
#              c1      c2     c3
# fruits    mango  banana  lichy
# flowers    rose    bela   lily
# veg      potato    bean  chili

# %%
std = {
     "student1": {
    "name": "Saikat Sarker",
    "grade" : 11,
     "roll": 10,
     "Id No": 123450
    },
    "student2": {
    "name": "Surjo Sarker",
    "class": "10th",
     "roll": 11,
     "Id No": 123460
    },
}

# %%
std
# Out:
# {'student1': {'name': 'Saikat Sarker',
#   'grade': 11,
#   'roll': 10,
#   'Id No': 123450},
#  'student2': {'name': 'Surjo Sarker',
#   'class': '10th',
#   'roll': 11,
#   'Id No': 123460}}

# %%
s = pd.DataFrame(std)

# %%
s
# Out:
#             student1      student2
# name   Saikat Sarker  Surjo Sarker
# grade             11           NaN
# roll              10            11
# Id No         123450        123460
# class            NaN          10th

# %%
import pandas as pd

# %%
s = pd.read_excel('std.xlsx')           #for csv file: pd.read_csv('filename.csv')
s
# Out:
#      Name Class  Roll      ID Country
# 0   Karim  11th     1    1111      BD
# 1   Rahim  12th     2    1234      BD
# 2   Salam  10th     3  123545     Pak
# 3  Barkat   9th     4    5643   India
# 4  Jobbar  10th     5    1123     pak

# %%
df = pd.read_excel('VFA.xlsx')

# %%
df
# Out:
#         Row ID                 Unique Style Identifier  New or Existing Style  \
# 0   Log0024795                      A82V2SNTNWOVOUTNOT                    NaN
# 1   Log0024758                      A86QPMOTNWOVSHINOT                    NaN
# 2   Log0024745                      A87Y7SNTNWOVPANSEA                    NaN
# 3   Log0024737                      A878RMFTNWOVPANNOT                    NaN
# 4   Log0025008                      A87XDMOTNWOVLIGSEA                    NaN
# 5   Log0024957                      A87XEMOTNWOVBIBSEA                    NaN
# 6   Log0025126                      A86NTMOTNWOVOUTNOT                    NaN
# 7   Log0025124                      A86P0MOTNWOVLIGSEA                    NaN
# 8   Log0025077                      A5J96MOTNWOVPANNOT                    NaN
# 9   Log0025139    NA4HCT-ACALMAR W VEST 6CONAWOVVESNOT                    NaN
# 10  Log0024988             NA4HPO-A-HURONCONAWOVVESNOT                    NaN
# ...

# %%
df.head()
# Out:
#        Row ID Unique Style Identifier  New or Existing Style New Style  \
# 0  Log0024795      A82V2SNTNWOVOUTNOT                    NaN     A82V2
# 1  Log0024758      A86QPMOTNWOVSHINOT                    NaN     A86QP
# 2  Log0024745      A87Y7SNTNWOVPANSEA                    NaN     A87Y7
# 3  Log0024737      A878RMFTNWOVPANNOT                    NaN     A878R
# 4  Log0025008      A87XDMOTNWOVLIGSEA                    NaN     A87XD
#
#    Existing Style  Style Season Date of submission VF Regional Location  \
# 0             NaN  A82V2   FA23         2023-01-09            Indonesia
# 1             NaN  A86QP   SP24         2023-01-06            Indonesia
# 2             NaN  A87Y7   FA24         2023-01-06            Indonesia
# 3             NaN  A878R   SP24         2023-01-06            Indonesia
# 4             NaN  A87XD   FA24         2023-01-12            Indonesia
#
#               SBU_New  ... Overall Score  \
# 0           Snowsport  ...           120
# ...

# %%
df.tail()
# Out:
#         Row ID            Unique Style Identifier  New or Existing Style  \
# 24  Log0024829  NA4HRW-A-RAYMI FZH WCONAWOVLIGNOT                    NaN
# 25  Log0024827   A-HURON VEST-NA4HPNCONAWOVVESNOT                    NaN
# 26  Log0024796                 A82WDSNTNWOVOUTNOT                    NaN
# 27  Log0024621                 A86NZMOTNWOVOUTNOT                    NaN
# 28  Log0024619                 A7WYOSNTNWOVOUTFIL                    NaN
#
#                New Style  Existing Style                 Style Season  \
# 24  NA4HRW-A-RAYMI FZH W             NaN  NA4HRW-A-RAYMI FZH W   SS24
# 25   A-HURON VEST-NA4HPN             NaN   A-HURON VEST-NA4HPN   SS24
# 26                 A82WD             NaN                 A82WD   FA23
# 27                 A86NZ             NaN                 A86NZ   SP24
# 28                 A7WYO             NaN                 A7WYO   FW23
#
#    Date of submission VF Regional Location              SBU_New  ...  \
# ...

# %%
df.head(10)
# Out:
#        Row ID               Unique Style Identifier  New or Existing Style  \
# 0  Log0024795                    A82V2SNTNWOVOUTNOT                    NaN
# 1  Log0024758                    A86QPMOTNWOVSHINOT                    NaN
# 2  Log0024745                    A87Y7SNTNWOVPANSEA                    NaN
# 3  Log0024737                    A878RMFTNWOVPANNOT                    NaN
# 4  Log0025008                    A87XDMOTNWOVLIGSEA                    NaN
# 5  Log0024957                    A87XEMOTNWOVBIBSEA                    NaN
# 6  Log0025126                    A86NTMOTNWOVOUTNOT                    NaN
# 7  Log0025124                    A86P0MOTNWOVLIGSEA                    NaN
# 8  Log0025077                    A5J96MOTNWOVPANNOT                    NaN
# 9  Log0025139  NA4HCT-ACALMAR W VEST 6CONAWOVVESNOT                    NaN
#
#                  New Style  Existing Style                    Style Season  \
# ...

# %%
df.tail(10)
# Out:
#         Row ID                Unique Style Identifier  New or Existing Style  \
# 19  Log0024881                     A86P2MOTNWOVOUTNOT                    NaN
# 20  Log0024879                     A87FEMOTNWOVPANNOT                    NaN
# 21  Log0024878                     A86R6MOTNWOVOUTNOT                    NaN
# 22  Log0024873                     A87XFSNTNWOVOUTSEA                    NaN
# 23  Log0024833  NA4HTR-RAINFOREST OP S WCONAWOVLIGSEA                    NaN
# 24  Log0024829      NA4HRW-A-RAYMI FZH WCONAWOVLIGNOT                    NaN
# 25  Log0024827       A-HURON VEST-NA4HPNCONAWOVVESNOT                    NaN
# 26  Log0024796                     A82WDSNTNWOVOUTNOT                    NaN
# 27  Log0024621                     A86NZMOTNWOVOUTNOT                    NaN
# 28  Log0024619                     A7WYOSNTNWOVOUTFIL                    NaN
#
#                    New Style  Existing Style                     Style Season  \
# ...

# %%
df.shape
# Out:
# (29, 72)

# %%
rows,colums = df.shape

# %%
rows
# Out:
# 29

# %%
colums
# Out:
# 72

# %%
df.values
# Out:
# array([['Log0024795', 'A82V2SNTNWOVOUTNOT', nan, ..., nan, nan, nan],
#        ['Log0024758', 'A86QPMOTNWOVSHINOT', nan, ..., nan, nan, nan],
#        ['Log0024745', 'A87Y7SNTNWOVPANSEA', nan, ..., nan, nan, nan],
#        ...,
#        ['Log0024796', 'A82WDSNTNWOVOUTNOT', nan, ..., nan, nan, nan],
#        ['Log0024621', 'A86NZMOTNWOVOUTNOT', nan, ..., nan, nan, nan],
#        ['Log0024619', 'A7WYOSNTNWOVOUTFIL', nan, ..., nan, nan, nan]],
#       dtype=object)

# %%
df.columns
# Out:
# Index(['Row ID', 'Unique Style Identifier', 'New or Existing Style',
#        'New Style', 'Existing Style', 'Style', 'Season', 'Date of submission',
#        'VF Regional Location', 'SBU_New', 'SBU', 'Brand_New', 'Brand',
#        'Product Main Category_New', 'Product Main Category',
#        'Product Sub Category_New', 'Product Sub Category',
#        'Special construction_New', 'Special construction', 'Complexity',
#        'Style Status', 'FFC - Factory Name', 'Factory FFC', 'Factory Name',
#        'Country of Origin', 'Vendor FFC', 'Vendor Name', 'Sample type',
#        'E-pattern & pattern overlay', 'Measurement sheet',
#        'Sample checklist / BOM', 'Reference Sample', 'Packaging',
#        'Remarks by Sourcing', 'Sample approval owned by',
#        'Submission form updated by', 'TD name', 'TD Email', 'CFT Name',
#        'CFT email', 'TVCP', 'TVCP Remarks', 'Approval Result',
#        'Brand Approval Result', 'Sample Out Date', 'Review Type', 'Dropped',
# ...

# %%
df.index
# Out:
# RangeIndex(start=0, stop=29, step=1)

# %%
s.values
# Out:
# array([['Karim', '11th', 1, 1111, 'BD'],
#        ['Rahim', '12th', 2, 1234, 'BD'],
#        ['Salam', '10th', 3, 123545, 'Pak'],
#        ['Barkat', '9th', 4, 5643, 'India'],
#        ['Jobbar', '10th', 5, 1123, 'pak']], dtype=object)

# %%
df.head()
# Out:
#        Row ID Unique Style Identifier  New or Existing Style New Style  \
# 0  Log0024795      A82V2SNTNWOVOUTNOT                    NaN     A82V2
# 1  Log0024758      A86QPMOTNWOVSHINOT                    NaN     A86QP
# 2  Log0024745      A87Y7SNTNWOVPANSEA                    NaN     A87Y7
# 3  Log0024737      A878RMFTNWOVPANNOT                    NaN     A878R
# 4  Log0025008      A87XDMOTNWOVLIGSEA                    NaN     A87XD
#
#    Existing Style  Style Season Date of submission VF Regional Location  \
# 0             NaN  A82V2   FA23         2023-01-09            Indonesia
# 1             NaN  A86QP   SP24         2023-01-06            Indonesia
# 2             NaN  A87Y7   FA24         2023-01-06            Indonesia
# 3             NaN  A878R   SP24         2023-01-06            Indonesia
# 4             NaN  A87XD   FA24         2023-01-12            Indonesia
#
#               SBU_New  ... Overall Score  \
# 0           Snowsport  ...           120
# ...

# %%
df.Style
# Out:
# 0                         A82V2
# 1                         A86QP
# 2                         A87Y7
# 3                         A878R
# 4                         A87XD
# 5                         A87XE
# 6                         A86NT
# 7                         A86P0
# 8                         A5J96
# 9       NA4HCT-ACALMAR W VEST 6
# 10               NA4HPO-A-HURON
# 11           NA4HS7-A-KENDALL W
# 12             NA4HXC-OBEY VEST
# 13    NA4H9Y-A-COUBERTIN ANORAK
# 14        NA4GE9-NORTHFARER 2.0
# 15      NA4HXD-OBEY EPOCH SHELL
# 16                        A86NW
# 17                        A86NV
# 18                        A86P3
# 19                        A86P2
# 20                        A87FE
# 21                        A86R6
# 22                        A87XF
# 23     NA4HTR-RAINFOREST OP S W
# 24         NA4HRW-A-RAYMI FZH W
# 25          A-HURON VEST-NA4HPN
# 26                        A82WD
# 27                        A86NZ
# 28                        A7WYO
# ...

# %%
df[['Row ID']]
# Out:
#         Row ID
# 0   Log0024795
# 1   Log0024758
# 2   Log0024745
# 3   Log0024737
# 4   Log0025008
# 5   Log0024957
# 6   Log0025126
# 7   Log0025124
# 8   Log0025077
# 9   Log0025139
# 10  Log0024988
# 11  Log0024987
# 12  Log0024986
# 13  Log0024985
# 14  Log0024984
# 15  Log0024983
# 16  Log0024887
# 17  Log0024886
# 18  Log0024882
# 19  Log0024881
# 20  Log0024879
# 21  Log0024878
# 22  Log0024873
# 23  Log0024833
# 24  Log0024829
# 25  Log0024827
# 26  Log0024796
# 27  Log0024621
# 28  Log0024619

# %%
df.Season.head(10)
# Out:
# 0    FA23
# 1    SP24
# 2    FA24
# 3    SP24
# 4    FA24
# 5    FA24
# 6    SP24
# 7    SP24
# 8    FA23
# 9    FW23
# Name: Season, dtype: object

# %%
df[['Date of submission']].head(12)
# Out:
#    Date of submission
# 0          2023-01-09
# 1          2023-01-06
# 2          2023-01-06
# 3          2023-01-06
# 4          2023-01-12
# 5          2023-01-11
# 6          2023-01-13
# 7          2023-01-13
# 8          2023-01-12
# 9          2023-01-13
# 10         2023-01-11
# 11         2023-01-11

# %%
df[['Row ID','VF Regional Location','Date of submission']].head(8)
# Out:
#        Row ID VF Regional Location Date of submission
# 0  Log0024795            Indonesia         2023-01-09
# 1  Log0024758            Indonesia         2023-01-06
# 2  Log0024745            Indonesia         2023-01-06
# 3  Log0024737            Indonesia         2023-01-06
# 4  Log0025008            Indonesia         2023-01-12
# 5  Log0024957            Indonesia         2023-01-11
# 6  Log0025126            Indonesia         2023-01-13
# 7  Log0025124            Indonesia         2023-01-13

# %%
df['Date of submission'].sort_values()
# Out:
# 28   2023-01-04
# 27   2023-01-04
# 1    2023-01-06
# 2    2023-01-06
# 3    2023-01-06
# 26   2023-01-09
# 25   2023-01-09
# 24   2023-01-09
# 23   2023-01-09
# 0    2023-01-09
# 19   2023-01-10
# 22   2023-01-10
# 21   2023-01-10
# 20   2023-01-10
# 18   2023-01-10
# 16   2023-01-10
# 17   2023-01-10
# 5    2023-01-11
# 10   2023-01-11
# 13   2023-01-11
# 12   2023-01-11
# 11   2023-01-11
# 15   2023-01-11
# 14   2023-01-11
# 8    2023-01-12
# 4    2023-01-12
# 9    2023-01-13
# 7    2023-01-13
# 6    2023-01-13
# Name: Date of submission, dtype: datetime64[ns]

# %%
df['Row ID'].sort_values(ascending=False)
# Out:
# 9     Log0025139
# 6     Log0025126
# 7     Log0025124
# 8     Log0025077
# 4     Log0025008
# 10    Log0024988
# 11    Log0024987
# 12    Log0024986
# 13    Log0024985
# 14    Log0024984
# 15    Log0024983
# 5     Log0024957
# 16    Log0024887
# 17    Log0024886
# 18    Log0024882
# 19    Log0024881
# 20    Log0024879
# 21    Log0024878
# 22    Log0024873
# 23    Log0024833
# 24    Log0024829
# 25    Log0024827
# 26    Log0024796
# 0     Log0024795
# 1     Log0024758
# 2     Log0024745
# 3     Log0024737
# 27    Log0024621
# 28    Log0024619
# Name: Row ID, dtype: object

# %%
df.sort_values('Row ID',ascending =  False ).head(15)
# Out:
#         Row ID                 Unique Style Identifier  New or Existing Style  \
# 9   Log0025139    NA4HCT-ACALMAR W VEST 6CONAWOVVESNOT                    NaN
# 6   Log0025126                      A86NTMOTNWOVOUTNOT                    NaN
# 7   Log0025124                      A86P0MOTNWOVLIGSEA                    NaN
# 8   Log0025077                      A5J96MOTNWOVPANNOT                    NaN
# 4   Log0025008                      A87XDMOTNWOVLIGSEA                    NaN
# 10  Log0024988             NA4HPO-A-HURONCONAWOVVESNOT                    NaN
# 11  Log0024987         NA4HS7-A-KENDALL WCONAWOVLIGNOT                    NaN
# 12  Log0024986           NA4HXC-OBEY VESTCONAWOVVESNOT                    NaN
# 13  Log0024985  NA4H9Y-A-COUBERTIN ANORAKCONAWOVLIGNOT                    NaN
# 14  Log0024984      NA4GE9-NORTHFARER 2.0CONAWOVLIGNOT                    NaN
# 15  Log0024983    NA4HXD-OBEY EPOCH SHELLCONAWOVLIGSEA                    NaN
# ...

# %%
df.describe()
# Out:
#        New or Existing Style  Existing Style   Factory FFC    Vendor FFC  \
# count                    0.0             0.0     29.000000     29.000000
# mean                     NaN             NaN  40325.448276  20881.827586
# std                      NaN             NaN   9277.221658   5593.345141
# min                      NaN             NaN  15396.000000  12722.000000
# 25%                      NaN             NaN  35577.000000  12722.000000
# 50%                      NaN             NaN  35577.000000  24582.000000
# 75%                      NaN             NaN  50017.000000  24582.000000
# max                      NaN             NaN  63503.000000  26163.000000
#
#        Packaging  Remarks by Sourcing  TVCP Remarks  Brand Approval Result  \
# count        0.0                  0.0           0.0                    0.0
# mean         NaN                  NaN           NaN                    NaN
# std          NaN                  NaN           NaN                    NaN
# ...

# %%
df.corr()
# Out:
# C:\Users\T\AppData\Local\Temp\ipykernel_6292\1134722465.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr()
#                           New or Existing Style  Existing Style  Factory FFC  \
# New or Existing Style                       NaN             NaN          NaN
# Existing Style                              NaN             NaN          NaN
# Factory FFC                                 NaN             NaN     1.000000
# Vendor FFC                                  NaN             NaN    -0.649947
# Packaging                                   NaN             NaN          NaN
# Remarks by Sourcing                         NaN             NaN          NaN
# TVCP Remarks                                NaN             NaN          NaN
# ...

# %%
df['Overall Score']>100
# Out:
# 0      True
# 1     False
# 2      True
# 3     False
# 4     False
# 5     False
# 6     False
# 7      True
# 8     False
# 9     False
# 10     True
# 11     True
# 12     True
# 13     True
# 14     True
# 15     True
# 16     True
# 17     True
# 18     True
# 19     True
# 20    False
# 21     True
# 22     True
# 23     True
# 24     True
# 25     True
# 26     True
# 27     True
# 28     True
# Name: Overall Score, dtype: bool

# %%
df[df['Overall Score']>100]
# Out:
#         Row ID                 Unique Style Identifier  New or Existing Style  \
# 0   Log0024795                      A82V2SNTNWOVOUTNOT                    NaN
# 2   Log0024745                      A87Y7SNTNWOVPANSEA                    NaN
# 7   Log0025124                      A86P0MOTNWOVLIGSEA                    NaN
# 10  Log0024988             NA4HPO-A-HURONCONAWOVVESNOT                    NaN
# 11  Log0024987         NA4HS7-A-KENDALL WCONAWOVLIGNOT                    NaN
# 12  Log0024986           NA4HXC-OBEY VESTCONAWOVVESNOT                    NaN
# 13  Log0024985  NA4H9Y-A-COUBERTIN ANORAKCONAWOVLIGNOT                    NaN
# 14  Log0024984      NA4GE9-NORTHFARER 2.0CONAWOVLIGNOT                    NaN
# 15  Log0024983    NA4HXD-OBEY EPOCH SHELLCONAWOVLIGSEA                    NaN
# 16  Log0024887                      A86NWMOTNWOVOUTNOT                    NaN
# 17  Log0024886                      A86NVMOTNWOVOUTNOT                    NaN
# ...

# %%
df[df['VF Regional Location'] =='Indonesia']
# Out:
#         Row ID Unique Style Identifier  New or Existing Style New Style  \
# 0   Log0024795      A82V2SNTNWOVOUTNOT                    NaN     A82V2
# 1   Log0024758      A86QPMOTNWOVSHINOT                    NaN     A86QP
# 2   Log0024745      A87Y7SNTNWOVPANSEA                    NaN     A87Y7
# 3   Log0024737      A878RMFTNWOVPANNOT                    NaN     A878R
# 4   Log0025008      A87XDMOTNWOVLIGSEA                    NaN     A87XD
# 5   Log0024957      A87XEMOTNWOVBIBSEA                    NaN     A87XE
# 6   Log0025126      A86NTMOTNWOVOUTNOT                    NaN     A86NT
# 7   Log0025124      A86P0MOTNWOVLIGSEA                    NaN     A86P0
# 8   Log0025077      A5J96MOTNWOVPANNOT                    NaN     A5J96
# 16  Log0024887      A86NWMOTNWOVOUTNOT                    NaN     A86NW
# 17  Log0024886      A86NVMOTNWOVOUTNOT                    NaN     A86NV
# 18  Log0024882      A86P3MOTNWOVOUTNOT                    NaN     A86P3
# ...

# %%
df[(df['VF Regional Location'] == 'Indonesia') | (df['VF Regional Location'] == 'Cambodia')]
# Out:
#         Row ID                 Unique Style Identifier  New or Existing Style  \
# 0   Log0024795                      A82V2SNTNWOVOUTNOT                    NaN
# 1   Log0024758                      A86QPMOTNWOVSHINOT                    NaN
# 2   Log0024745                      A87Y7SNTNWOVPANSEA                    NaN
# 3   Log0024737                      A878RMFTNWOVPANNOT                    NaN
# 4   Log0025008                      A87XDMOTNWOVLIGSEA                    NaN
# 5   Log0024957                      A87XEMOTNWOVBIBSEA                    NaN
# 6   Log0025126                      A86NTMOTNWOVOUTNOT                    NaN
# 7   Log0025124                      A86P0MOTNWOVLIGSEA                    NaN
# 8   Log0025077                      A5J96MOTNWOVPANNOT                    NaN
# 9   Log0025139    NA4HCT-ACALMAR W VEST 6CONAWOVVESNOT                    NaN
# 10  Log0024988             NA4HPO-A-HURONCONAWOVVESNOT                    NaN
# ...

# %%
df[df['VF Regional Location'].isin(['Cambodia','Indonesia'])]
# Out:
#         Row ID                 Unique Style Identifier  New or Existing Style  \
# 0   Log0024795                      A82V2SNTNWOVOUTNOT                    NaN
# 1   Log0024758                      A86QPMOTNWOVSHINOT                    NaN
# 2   Log0024745                      A87Y7SNTNWOVPANSEA                    NaN
# 3   Log0024737                      A878RMFTNWOVPANNOT                    NaN
# 4   Log0025008                      A87XDMOTNWOVLIGSEA                    NaN
# 5   Log0024957                      A87XEMOTNWOVBIBSEA                    NaN
# 6   Log0025126                      A86NTMOTNWOVOUTNOT                    NaN
# 7   Log0025124                      A86P0MOTNWOVLIGSEA                    NaN
# 8   Log0025077                      A5J96MOTNWOVPANNOT                    NaN
# 9   Log0025139    NA4HCT-ACALMAR W VEST 6CONAWOVVESNOT                    NaN
# 10  Log0024988             NA4HPO-A-HURONCONAWOVVESNOT                    NaN
# ...

# %%
df[df['VF Regional Location'].isin(['Cambodia'])]
# Out:
#         Row ID                 Unique Style Identifier  New or Existing Style  \
# 9   Log0025139    NA4HCT-ACALMAR W VEST 6CONAWOVVESNOT                    NaN
# 10  Log0024988             NA4HPO-A-HURONCONAWOVVESNOT                    NaN
# 11  Log0024987         NA4HS7-A-KENDALL WCONAWOVLIGNOT                    NaN
# 12  Log0024986           NA4HXC-OBEY VESTCONAWOVVESNOT                    NaN
# 13  Log0024985  NA4H9Y-A-COUBERTIN ANORAKCONAWOVLIGNOT                    NaN
# 14  Log0024984      NA4GE9-NORTHFARER 2.0CONAWOVLIGNOT                    NaN
# 15  Log0024983    NA4HXD-OBEY EPOCH SHELLCONAWOVLIGSEA                    NaN
# 23  Log0024833   NA4HTR-RAINFOREST OP S WCONAWOVLIGSEA                    NaN
# 24  Log0024829       NA4HRW-A-RAYMI FZH WCONAWOVLIGNOT                    NaN
# 25  Log0024827        A-HURON VEST-NA4HPNCONAWOVVESNOT                    NaN
#
#                     New Style  Existing Style                      Style  \
# ...
